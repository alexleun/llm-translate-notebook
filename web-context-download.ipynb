# %%
# Get the web contain in Japan novel, work with jp site
import requests
from bs4 import BeautifulSoup

def find_between(s, start, end):
    return s.split(start)[1].split(end)[0]

# %%
# Get subtitle and url from source_url
novel_num = "n8733gf"
base_url = "https://ncode.syosetu.com/"
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
response = requests.get(base_url+novel_num+'/', headers=headers)
#response = requests.get(base_url+novel_num+'/?p=3', headers=headers)

soup = BeautifulSoup(response.content, "html.parser")
novel_title = find_between(str(soup.find(class_="novel_title")), ">", "<")
index_box = soup.find(class_="index_box")
urls = index_box.find_all(class_="subtitle")
sublist = []
for url in urls:
    ut = find_between(str(url),'/">','</a>')
    ul = base_url+find_between(str(url),'href="/','">')
    sublist.append([ut, ul])

txt=novel_title+'\n'
e = 0
for subl in sublist:
    print(subl[1])
    e += 1
    txt=txt+'Chapter '+str(e)+': '+subl[0]+'\n'
    response = requests.get(subl[1], headers=headers)
    soup = BeautifulSoup(response.content, "html.parser")
    a = soup.find_all(class_="novel_view")
    for b in a:
        c=b.get_text(separator = '</p>').replace('</p>','')
    txt=txt+c+'\n'

# write to text file.
text_file = open(novel_num+".txt", "w", encoding='UTF-8')
if text_file.write(txt) != len(txt):
    print("Failure! String not written to text file.")
text_file.close()
# Out:
# https://ncode.syosetu.com/n8733gf/1/
# https://ncode.syosetu.com/n8733gf/2/
# https://ncode.syosetu.com/n8733gf/3/
# https://ncode.syosetu.com/n8733gf/4/
# https://ncode.syosetu.com/n8733gf/5/
# https://ncode.syosetu.com/n8733gf/6/
# https://ncode.syosetu.com/n8733gf/7/
# https://ncode.syosetu.com/n8733gf/8/
# https://ncode.syosetu.com/n8733gf/9/
# https://ncode.syosetu.com/n8733gf/10/
# https://ncode.syosetu.com/n8733gf/11/
# https://ncode.syosetu.com/n8733gf/12/
# https://ncode.syosetu.com/n8733gf/13/
# https://ncode.syosetu.com/n8733gf/14/
# https://ncode.syosetu.com/n8733gf/15/
# https://ncode.syosetu.com/n8733gf/16/
# https://ncode.syosetu.com/n8733gf/17/
# https://ncode.syosetu.com/n8733gf/18/
# https://ncode.syosetu.com/n8733gf/19/
# https://ncode.syosetu.com/n8733gf/20/
# https://ncode.syosetu.com/n8733gf/21/
# https://ncode.syosetu.com/n8733gf/22/
# https://ncode.syosetu.com/n8733gf/23/
# https://ncode.syosetu.com/n8733gf/24/
# https://ncode.syosetu.com/n8733gf/25/
# https://ncode.syosetu.com/n8733gf/26/
# https://ncode.syosetu.com/n8733gf/27/
# https://ncode.syosetu.com/n8733gf/28/
# https://ncode.syosetu.com/n8733gf/29/
# https://ncode.syosetu.com/n8733gf/30/
# https://ncode.syosetu.com/n8733gf/31/
# https://ncode.syosetu.com/n8733gf/32/
# https://ncode.syosetu.com/n8733gf/33/
# https://ncode.syosetu.com/n8733gf/34/
# https://ncode.syosetu.com/n8733gf/35/
# https://ncode.syosetu.com/n8733gf/36/
# https://ncode.syosetu.com/n8733gf/37/
# https://ncode.syosetu.com/n8733gf/38/
# https://ncode.syosetu.com/n8733gf/39/
# https://ncode.syosetu.com/n8733gf/40/
# https://ncode.syosetu.com/n8733gf/41/
# https://ncode.syosetu.com/n8733gf/42/
# https://ncode.syosetu.com/n8733gf/43/
# https://ncode.syosetu.com/n8733gf/44/
# https://ncode.syosetu.com/n8733gf/45/
# https://ncode.syosetu.com/n8733gf/46/
# https://ncode.syosetu.com/n8733gf/47/
# https://ncode.syosetu.com/n8733gf/48/
# https://ncode.syosetu.com/n8733gf/49/
# https://ncode.syosetu.com/n8733gf/50/
# https://ncode.syosetu.com/n8733gf/51/
# https://ncode.syosetu.com/n8733gf/52/
# https://ncode.syosetu.com/n8733gf/53/
# https://ncode.syosetu.com/n8733gf/54/
# https://ncode.syosetu.com/n8733gf/55/
# https://ncode.syosetu.com/n8733gf/56/
# https://ncode.syosetu.com/n8733gf/57/
# https://ncode.syosetu.com/n8733gf/58/
# https://ncode.syosetu.com/n8733gf/59/
# https://ncode.syosetu.com/n8733gf/60/
# https://ncode.syosetu.com/n8733gf/61/
# https://ncode.syosetu.com/n8733gf/62/
# https://ncode.syosetu.com/n8733gf/63/
# https://ncode.syosetu.com/n8733gf/64/
# https://ncode.syosetu.com/n8733gf/65/
# https://ncode.syosetu.com/n8733gf/66/
# https://ncode.syosetu.com/n8733gf/67/
# https://ncode.syosetu.com/n8733gf/68/
# https://ncode.syosetu.com/n8733gf/69/
# https://ncode.syosetu.com/n8733gf/70/
# https://ncode.syosetu.com/n8733gf/71/
# https://ncode.syosetu.com/n8733gf/72/
# https://ncode.syosetu.com/n8733gf/73/
# https://ncode.syosetu.com/n8733gf/74/
# https://ncode.syosetu.com/n8733gf/75/
# https://ncode.syosetu.com/n8733gf/76/
# https://ncode.syosetu.com/n8733gf/77/
# https://ncode.syosetu.com/n8733gf/78/
# https://ncode.syosetu.com/n8733gf/79/
# https://ncode.syosetu.com/n8733gf/80/
# https://ncode.syosetu.com/n8733gf/81/
# https://ncode.syosetu.com/n8733gf/82/
# https://ncode.syosetu.com/n8733gf/83/
# https://ncode.syosetu.com/n8733gf/84/
# https://ncode.syosetu.com/n8733gf/85/
# https://ncode.syosetu.com/n8733gf/86/
# https://ncode.syosetu.com/n8733gf/87/
# https://ncode.syosetu.com/n8733gf/88/
# https://ncode.syosetu.com/n8733gf/89/
# https://ncode.syosetu.com/n8733gf/90/
# https://ncode.syosetu.com/n8733gf/91/
# https://ncode.syosetu.com/n8733gf/92/
# https://ncode.syosetu.com/n8733gf/93/
# https://ncode.syosetu.com/n8733gf/94/
# https://ncode.syosetu.com/n8733gf/95/
# https://ncode.syosetu.com/n8733gf/96/
# https://ncode.syosetu.com/n8733gf/97/
# https://ncode.syosetu.com/n8733gf/98/
# https://ncode.syosetu.com/n8733gf/99/
# https://ncode.syosetu.com/n8733gf/100/
